# %%
# %sql
insert overwrite table  ${banfield_catalog}.bfdw_silver.cmn_tbcmdpetvststatus
( 
 dw_pet_vst_status_id
 ,pet_vst_status_cd
 ,pet_vst_status_descr
 ,dw_create_dt
 ,dw_begin_eff_dt
 ,dw_end_eff_dt
 ,dw_deleted_ind
 ,dw_curr_row_ind
 ,dw_job_id
 ,dw_load_dt
 ,fw_createdts
 ,fw_modifiedts
 ,fw_filename
 ,rowhash
 )
select
 dw_pet_vst_status_id
 ,pet_vst_status_cd
 ,pet_vst_status_descr
 ,dw_create_dt
 ,dw_begin_eff_dt
 ,dw_end_eff_dt
 ,dw_deleted_ind
 ,dw_curr_row_ind
 ,dw_job_id
 ,dw_load_dt
 ,fw_createdts
 ,fw_modifiedts
 ,fw_filename
 ,rowhash
from  ${banfield_catalog}.bfdw_bronze.cmn_tbcmdpetvststatus
where record_status = 'valid';
