# %%
# %sql
insert overwrite table ${banfield_catalog}.bfdw_bronze.cmn_tbcmdcurrentitem
(   
 inventoryid
,inventoryrootid
,item_descr
,item_class
,item_primary_typ
,item_secondary_typ
,item_status
,prdct_or_srvc
,drug_desc
,item_coupon_typ
,price_capped_bndl_mbr_flg
,default_unit_price_lvl_01
,default_unit_price_lvl_02
,default_unit_price_lvl_03
,default_unit_price_lvl_04
,default_unit_price_lvl_05
,default_unit_price_lvl_06
,default_unit_price_lvl_07
,default_unit_price_lvl_08
,default_unit_price_lvl_09
,item_taxable_flg
,pricing_rule
,license_tag_fee_flg
,item_prev_care_flg
,dea_controlled_flg
,item_male_flg
,item_female_flg
,item_neuter_flg
,item_spay_flg
,item_canine_flg
,item_feline_flg
,item_primary_typ_cd
,item_secondary_typ_cd
,dw_deleted_ind
,dw_job_id
,dw_load_dt
,audit_category_cd
,audit_category_desc
,default_packing_price_lvl_01
,default_packing_price_lvl_02
,default_packing_price_lvl_03
,default_packing_price_lvl_04
,default_packing_price_lvl_05
,default_packing_price_lvl_06
,default_packing_price_lvl_07
,reference_lab_flg
,default_packing_price_lvl_08
,default_packing_price_lvl_09
,default_packing_price_lvl_10
,default_unit_price_lvl_10
,default_packing_price_lvl_11
,default_unit_price_lvl_11
,default_packing_price_lvl_12
,default_unit_price_lvl_12
,default_packing_price_lvl_13
,default_unit_price_lvl_13
,default_packing_price_lvl_14
,default_unit_price_lvl_14
,default_packing_price_lvl_15
,default_unit_price_lvl_15
,default_packing_price_lvl_16
,default_unit_price_lvl_16
,default_packing_price_lvl_17
,default_unit_price_lvl_17
,default_packing_price_lvl_18
,default_unit_price_lvl_18
,default_packing_price_lvl_19
,default_unit_price_lvl_19
,default_packing_price_lvl_20
,default_unit_price_lvl_20
,prdct_cost_amt
,default_packing_price_lvl_21
,default_unit_price_lvl_21
,default_packing_price_lvl_22
,default_unit_price_lvl_22
,default_packing_price_lvl_23
,default_unit_price_lvl_23
,default_packing_price_lvl_24
,default_unit_price_lvl_24
,default_packing_price_lvl_25
,default_unit_price_lvl_25
,item_gl_account_num
,item_gl_account_descr
,item_updt_cost_with_price_flg
,item_user_editable_flg
,non_sx_anesthesia_flg
,healthy_sx_bndl_flg
,item_tertiary_typ_cd
,item_tertiary_typ
,management_category_cd
,management_category
,default_mfg_nam
,documentation_cd
,documentation_cd_desc
,fda_prescription_flg
,item_formulary_nam
,product_grp_nam
,prev_care_useful_life_days
,item_unit
,item_src_system_cd
,multiple_price_area_flg
,ft_hw_item_dose_cnt
,delivery_method_nam
,dw_item_descriptiontext_id
,item_descr_spanish_us
,item_descr_spanish_pr
,item_areaid
,item_area_record_start_dt
,item_area_record_end_dt
,item_start_dt
,item_end_dt
,drug_form_desc
,default_packing_price_lvl_26
,default_unit_price_lvl_26
,default_packing_price_lvl_27
,default_unit_price_lvl_27
,default_packing_price_lvl_28
,default_unit_price_lvl_28
,default_packing_price_lvl_29
,default_unit_price_lvl_29
,default_packing_price_lvl_30
,default_unit_price_lvl_30
,default_packing_price_lvl_31
,default_unit_price_lvl_31
,default_packing_price_lvl_32
,default_unit_price_lvl_32
,default_packing_price_lvl_33
,default_unit_price_lvl_33
,default_packing_price_lvl_34
,default_unit_price_lvl_34
,default_packing_price_lvl_35
,default_unit_price_lvl_35
,default_packing_price_lvl_36
,default_unit_price_lvl_36
,default_packing_price_lvl_37
,default_unit_price_lvl_37
,default_packing_price_lvl_38
,default_unit_price_lvl_38
,default_packing_price_lvl_39
,default_unit_price_lvl_39
,default_packing_price_lvl_40
,default_unit_price_lvl_40
,default_packing_price_lvl_41
,default_unit_price_lvl_41
,default_packing_price_lvl_42
,default_unit_price_lvl_42
,default_packing_price_lvl_43
,default_unit_price_lvl_43
,default_packing_price_lvl_44
,default_unit_price_lvl_44
,default_packing_price_lvl_45
,default_unit_price_lvl_45
,default_packing_price_lvl_46
,default_unit_price_lvl_46
,default_packing_price_lvl_47
,default_unit_price_lvl_47
,default_packing_price_lvl_48
,default_unit_price_lvl_48
,default_packing_price_lvl_49
,default_unit_price_lvl_49
,default_packing_price_lvl_50
,default_unit_price_lvl_50
,default_packing_price_lvl_51
,default_unit_price_lvl_51
,default_packing_price_lvl_52
,default_unit_price_lvl_52
,default_packing_price_lvl_53
,default_unit_price_lvl_53
,default_packing_price_lvl_54
,default_unit_price_lvl_54
,default_packing_price_lvl_55
,default_unit_price_lvl_55
,default_packing_price_lvl_56
,default_unit_price_lvl_56
,default_packing_price_lvl_57
,default_unit_price_lvl_57
,default_packing_price_lvl_58
,default_unit_price_lvl_58
,default_packing_price_lvl_59
,default_unit_price_lvl_59
,default_packing_price_lvl_60
,default_unit_price_lvl_60
,default_packing_price_lvl_61
,default_unit_price_lvl_61
,default_packing_price_lvl_62
,default_unit_price_lvl_62
,default_packing_price_lvl_63
,default_unit_price_lvl_63
,default_packing_price_lvl_64
,default_unit_price_lvl_64
,default_packing_price_lvl_65
,default_unit_price_lvl_65
,item_shippable_flg
,fw_createdts
,fw_modifiedts
,fw_filename
,rowhash
,record_status
)
select
 cast(inventoryid as bigint ) as inventoryid
,cast(inventoryrootid as bigint ) as inventoryrootid
,cast(item_descr as string ) as item_descr
,cast(item_class as string ) as item_class
,cast(item_primary_typ as string ) as item_primary_typ
,cast(item_secondary_typ as string ) as item_secondary_typ
,cast(item_status as string ) as item_status
,cast(prdct_or_srvc as string ) as prdct_or_srvc
,cast(drug_desc as string ) as drug_desc
,cast(item_coupon_typ as string ) as item_coupon_typ
,cast(price_capped_bndl_mbr_flg as string) as price_capped_bndl_mbr_flg
,cast(default_unit_price_lvl_01 as bigint) as default_unit_price_lvl_01
,cast(default_unit_price_lvl_02 as bigint) as default_unit_price_lvl_02
,cast(default_unit_price_lvl_03 as bigint) as default_unit_price_lvl_03
,cast(default_unit_price_lvl_04 as bigint) as default_unit_price_lvl_04
,cast(default_unit_price_lvl_05 as bigint) as default_unit_price_lvl_05
,cast(default_unit_price_lvl_06 as bigint) as default_unit_price_lvl_06
,cast(default_unit_price_lvl_07 as bigint) as default_unit_price_lvl_07
,cast(default_unit_price_lvl_08 as bigint) as default_unit_price_lvl_08
,cast(default_unit_price_lvl_09 as bigint) as default_unit_price_lvl_09
,cast(item_taxable_flg as string) as item_taxable_flg
,cast(pricing_rule as string) as pricing_rule
,cast(license_tag_fee_flg as string) as license_tag_fee_flg
,cast(item_prev_care_flg as string) as item_prev_care_flg
,cast(dea_controlled_flg as string) as dea_controlled_flg
,cast(item_male_flg as string) as item_male_flg
,cast(item_female_flg as string) as item_female_flg
,cast(item_neuter_flg as string) as item_neuter_flg
,cast(item_spay_flg as string) as item_spay_flg
,cast(item_canine_flg as string) as item_canine_flg
,cast(item_feline_flg as string) as item_feline_flg
,cast(item_primary_typ_cd as string) as item_primary_typ_cd
,cast(item_secondary_typ_cd as string) as item_secondary_typ_cd
,cast(dw_deleted_ind as bigint) as dw_deleted_ind
,cast(dw_job_id as bigint) as dw_job_id
,cast(dw_load_dt as timestamp) as dw_load_dt
,cast(audit_category_cd as string) as audit_category_cd
,cast(audit_category_desc as string) as audit_category_desc
,cast(default_packing_price_lvl_01 as bigint) as default_packing_price_lvl_01
,cast(default_packing_price_lvl_02 as bigint) as default_packing_price_lvl_02
,cast(default_packing_price_lvl_03 as bigint) as default_packing_price_lvl_03
,cast(default_packing_price_lvl_04 as bigint) as default_packing_price_lvl_04
,cast(default_packing_price_lvl_05 as bigint) as default_packing_price_lvl_05
,cast(default_packing_price_lvl_06 as bigint) as default_packing_price_lvl_06
,cast(default_packing_price_lvl_07 as bigint) as default_packing_price_lvl_07
,cast(reference_lab_flg as string) as reference_lab_flg
,cast(default_packing_price_lvl_08 as bigint) as default_packing_price_lvl_08
,cast(default_packing_price_lvl_09 as bigint) as default_packing_price_lvl_09
,cast(default_packing_price_lvl_10 as bigint) as default_packing_price_lvl_10
,cast(default_unit_price_lvl_10 as bigint) as default_unit_price_lvl_10
,cast(default_packing_price_lvl_11 as bigint) as default_packing_price_lvl_11
,cast(default_unit_price_lvl_11 as bigint) as default_unit_price_lvl_11
,cast(default_packing_price_lvl_12 as bigint) as default_packing_price_lvl_12
,cast(default_unit_price_lvl_12 as bigint) as default_unit_price_lvl_12
,cast(default_packing_price_lvl_13 as bigint) as default_packing_price_lvl_13
,cast(default_unit_price_lvl_13 as bigint) as default_unit_price_lvl_13
,cast(default_packing_price_lvl_14 as bigint) as default_packing_price_lvl_14
,cast(default_unit_price_lvl_14 as bigint) as default_unit_price_lvl_14
,cast(default_packing_price_lvl_15 as bigint) as default_packing_price_lvl_15
,cast(default_unit_price_lvl_15 as bigint) as default_unit_price_lvl_15
,cast(default_packing_price_lvl_16 as bigint) as default_packing_price_lvl_16
,cast(default_unit_price_lvl_16 as bigint) as default_unit_price_lvl_16
,cast(default_packing_price_lvl_17 as bigint) as default_packing_price_lvl_17
,cast(default_unit_price_lvl_17 as bigint) as default_unit_price_lvl_17
,cast(default_packing_price_lvl_18 as bigint) as default_packing_price_lvl_18
,cast(default_unit_price_lvl_18 as bigint) as default_unit_price_lvl_18
,cast(default_packing_price_lvl_19 as bigint) as default_packing_price_lvl_19
,cast(default_unit_price_lvl_19 as bigint) as default_unit_price_lvl_19
,cast(default_packing_price_lvl_20 as bigint) as default_packing_price_lvl_20
,cast(default_unit_price_lvl_20 as bigint) as default_unit_price_lvl_20
,cast(prdct_cost_amt as bigint) as prdct_cost_amt
,cast(default_packing_price_lvl_21 as bigint) as default_packing_price_lvl_21
,cast(default_unit_price_lvl_21 as bigint) as default_unit_price_lvl_21
,cast(default_packing_price_lvl_22 as bigint) as default_packing_price_lvl_22
,cast(default_unit_price_lvl_22 as bigint) as default_unit_price_lvl_22
,cast(default_packing_price_lvl_23 as bigint) as default_packing_price_lvl_23
,cast(default_unit_price_lvl_23 as bigint) as default_unit_price_lvl_23
,cast(default_packing_price_lvl_24 as bigint) as default_packing_price_lvl_24
,cast(default_unit_price_lvl_24 as bigint) as default_unit_price_lvl_24
,cast(default_packing_price_lvl_25 as bigint) as default_packing_price_lvl_25
,cast(default_unit_price_lvl_25 as bigint) as default_unit_price_lvl_25
,cast(item_gl_account_num as string) as item_gl_account_num
,cast(item_gl_account_descr as string) as item_gl_account_descr
,cast(item_updt_cost_with_price_flg as string) as item_updt_cost_with_price_flg
,cast(item_user_editable_flg as string) as item_user_editable_flg
,cast(non_sx_anesthesia_flg as string) as non_sx_anesthesia_flg
,cast(healthy_sx_bndl_flg as string) as healthy_sx_bndl_flg
,cast(item_tertiary_typ_cd as bigint) as item_tertiary_typ_cd
,cast(item_tertiary_typ as string) as item_tertiary_typ
,cast(management_category_cd as bigint) as management_category_cd
,cast(management_category as string) as management_category
,cast(default_mfg_nam as string) as default_mfg_nam
,cast(documentation_cd as bigint) as documentation_cd
,cast(documentation_cd_desc as string) as documentation_cd_desc
,cast(fda_prescription_flg as string) as fda_prescription_flg
,cast(item_formulary_nam as string) as item_formulary_nam
,cast(product_grp_nam as string) as product_grp_nam
,cast(prev_care_useful_life_days as bigint) as prev_care_useful_life_days
,cast(item_unit as string) as item_unit
,cast(item_src_system_cd as string) as item_src_system_cd
,cast(multiple_price_area_flg as string) as multiple_price_area_flg
,cast(ft_hw_item_dose_cnt as bigint) as ft_hw_item_dose_cnt
,cast(delivery_method_nam as string) as delivery_method_nam
,cast(dw_item_descriptiontext_id as bigint) as dw_item_descriptiontext_id
,cast(item_descr_spanish_us as string) as item_descr_spanish_us
,cast(item_descr_spanish_pr as string) as item_descr_spanish_pr
,cast(item_areaid as bigint) as item_areaid
,cast(item_area_record_start_dt as timestamp) as item_area_record_start_dt
,cast(item_area_record_end_dt as timestamp) as item_area_record_end_dt
,cast(item_start_dt as timestamp) as item_start_dt
,cast(item_end_dt as timestamp) as item_end_dt
,cast(drug_form_desc as string) as drug_form_desc
,cast(default_packing_price_lvl_26 as bigint) as default_packing_price_lvl_26
,cast(default_unit_price_lvl_26 as bigint) as default_unit_price_lvl_26
,cast(default_packing_price_lvl_27 as bigint) as default_packing_price_lvl_27
,cast(default_unit_price_lvl_27 as bigint) as default_unit_price_lvl_27
,cast(default_packing_price_lvl_28 as bigint) as default_packing_price_lvl_28
,cast(default_unit_price_lvl_28 as bigint) as default_unit_price_lvl_28
,cast(default_packing_price_lvl_29 as bigint) as default_packing_price_lvl_29
,cast(default_unit_price_lvl_29 as bigint) as default_unit_price_lvl_29
,cast(default_packing_price_lvl_30 as bigint) as default_packing_price_lvl_30
,cast(default_unit_price_lvl_30 as bigint) as default_unit_price_lvl_30
,cast(default_packing_price_lvl_31 as bigint) as default_packing_price_lvl_31
,cast(default_unit_price_lvl_31 as bigint) as default_unit_price_lvl_31
,cast(default_packing_price_lvl_32 as bigint) as default_packing_price_lvl_32
,cast(default_unit_price_lvl_32 as bigint) as default_unit_price_lvl_32
,cast(default_packing_price_lvl_33 as bigint) as default_packing_price_lvl_33
,cast(default_unit_price_lvl_33 as bigint) as default_unit_price_lvl_33
,cast(default_packing_price_lvl_34 as bigint) as default_packing_price_lvl_34
,cast(default_unit_price_lvl_34 as bigint) as default_unit_price_lvl_34
,cast(default_packing_price_lvl_35 as bigint) as default_packing_price_lvl_35
,cast(default_unit_price_lvl_35 as bigint) as default_unit_price_lvl_35
,cast(default_packing_price_lvl_36 as bigint) as default_packing_price_lvl_36
,cast(default_unit_price_lvl_36 as bigint) as default_unit_price_lvl_36
,cast(default_packing_price_lvl_37 as bigint) as default_packing_price_lvl_37
,cast(default_unit_price_lvl_37 as bigint) as default_unit_price_lvl_37
,cast(default_packing_price_lvl_38 as bigint) as default_packing_price_lvl_38
,cast(default_unit_price_lvl_38 as bigint) as default_unit_price_lvl_38
,cast(default_packing_price_lvl_39 as bigint) as default_packing_price_lvl_39
,cast(default_unit_price_lvl_39 as bigint) as default_unit_price_lvl_39
,cast(default_packing_price_lvl_40 as bigint) as default_packing_price_lvl_40
,cast(default_unit_price_lvl_40 as bigint) as default_unit_price_lvl_40
,cast(default_packing_price_lvl_41 as bigint) as default_packing_price_lvl_41
,cast(default_unit_price_lvl_41 as bigint) as default_unit_price_lvl_41
,cast(default_packing_price_lvl_42 as bigint) as default_packing_price_lvl_42
,cast(default_unit_price_lvl_42 as bigint) as default_unit_price_lvl_42
,cast(default_packing_price_lvl_43 as bigint) as default_packing_price_lvl_43
,cast(default_unit_price_lvl_43 as bigint) as default_unit_price_lvl_43
,cast(default_packing_price_lvl_44 as bigint) as default_packing_price_lvl_44
,cast(default_unit_price_lvl_44 as bigint) as default_unit_price_lvl_44
,cast(default_packing_price_lvl_45 as bigint) as default_packing_price_lvl_45
,cast(default_unit_price_lvl_45 as bigint) as default_unit_price_lvl_45
,cast(default_packing_price_lvl_46 as bigint) as default_packing_price_lvl_46
,cast(default_unit_price_lvl_46 as bigint) as default_unit_price_lvl_46
,cast(default_packing_price_lvl_47 as bigint) as default_packing_price_lvl_47
,cast(default_unit_price_lvl_47 as bigint) as default_unit_price_lvl_47
,cast(default_packing_price_lvl_48 as bigint) as default_packing_price_lvl_48
,cast(default_unit_price_lvl_48 as bigint) as default_unit_price_lvl_48
,cast(default_packing_price_lvl_49 as bigint) as default_packing_price_lvl_49
,cast(default_unit_price_lvl_49 as bigint) as default_unit_price_lvl_49
,cast(default_packing_price_lvl_50 as bigint) as default_packing_price_lvl_50
,cast(default_unit_price_lvl_50 as bigint) as default_unit_price_lvl_50
,cast(default_packing_price_lvl_51 as bigint) as default_packing_price_lvl_51
,cast(default_unit_price_lvl_51 as bigint) as default_unit_price_lvl_51
,cast(default_packing_price_lvl_52 as bigint) as default_packing_price_lvl_52
,cast(default_unit_price_lvl_52 as bigint) as default_unit_price_lvl_52
,cast(default_packing_price_lvl_53 as bigint) as default_packing_price_lvl_53
,cast(default_unit_price_lvl_53 as bigint) as default_unit_price_lvl_53
,cast(default_packing_price_lvl_54 as bigint) as default_packing_price_lvl_54
,cast(default_unit_price_lvl_54 as bigint) as default_unit_price_lvl_54
,cast(default_packing_price_lvl_55 as bigint) as default_packing_price_lvl_55
,cast(default_unit_price_lvl_55 as bigint) as default_unit_price_lvl_55
,cast(default_packing_price_lvl_56 as bigint) as default_packing_price_lvl_56
,cast(default_unit_price_lvl_56 as bigint) as default_unit_price_lvl_56
,cast(default_packing_price_lvl_57 as bigint) as default_packing_price_lvl_57
,cast(default_unit_price_lvl_57 as bigint) as default_unit_price_lvl_57
,cast(default_packing_price_lvl_58 as bigint) as default_packing_price_lvl_58
,cast(default_unit_price_lvl_58 as bigint) as default_unit_price_lvl_58
,cast(default_packing_price_lvl_59 as bigint) as default_packing_price_lvl_59
,cast(default_unit_price_lvl_59 as bigint) as default_unit_price_lvl_59
,cast(default_packing_price_lvl_60 as bigint) as default_packing_price_lvl_60
,cast(default_unit_price_lvl_60 as bigint) as default_unit_price_lvl_60
,cast(default_packing_price_lvl_61 as bigint) as default_packing_price_lvl_61
,cast(default_unit_price_lvl_61 as bigint) as default_unit_price_lvl_61
,cast(default_packing_price_lvl_62 as bigint) as default_packing_price_lvl_62
,cast(default_unit_price_lvl_62 as bigint) as default_unit_price_lvl_62
,cast(default_packing_price_lvl_63 as bigint) as default_packing_price_lvl_63
,cast(default_unit_price_lvl_63 as bigint) as default_unit_price_lvl_63
,cast(default_packing_price_lvl_64 as bigint) as default_packing_price_lvl_64
,cast(default_unit_price_lvl_64 as bigint) as default_unit_price_lvl_64
,cast(default_packing_price_lvl_65 as bigint) as default_packing_price_lvl_65
,cast(default_unit_price_lvl_65 as bigint) as default_unit_price_lvl_65
,cast(item_shippable_flg as string) as item_shippable_flg
,cast(ingestion_ts as timestamp) as fw_createdts
,current_timestamp as fw_modifiedts
,cast(source_file as string) as fw_filename
,sha2(COALESCE(trim(dw_item_id),''), 512) as rowhash
,case
    when (
          try_cast(dw_invc_line_status_id as string) is not null 
         )
  then 'valid'
  else 'invalid'
end as record_status
 
from ${banfield_catalog}.bfdw_iron.cmn_tbcmdcurrentitem
;
