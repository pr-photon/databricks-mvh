-- %%
%sql
insert overwrite table  ${banfield_catalog}.bfdw_silver.cmn_tb_cmd_current_hosp
( 
hosp_num,
    frmr_hosp_num,
    hosp_typ,
    petsmart_vet_srvcs_flg,
    hosp_abbrv,
    store_num,
    hosp_long_nam,
    hosp_short_nam,
    hosp_region,
    regional_vp_full_nam,
    regional_vp_first_nam,
    regional_vp_last_nam,
    field_drctr_area,
    field_drctr_full_nam,
    field_drctr_first_nam,
    field_drctr_last_nam,
    field_trainer_full_nam,
    field_trainer_first_nam,
    field_trainer_last_nam,
    medical_drctr_full_nam,
    medical_drctr_first_nam,
    medical_drctr_last_nam,
    prctc_cnsltnt_full_nam,
    prctc_cnsltnt_first_nam,
    prctc_cnsltnt_last_nam,
    cos_full_nam,
    cos_first_nam,
    cos_last_nam,
    shopping_center_nam,
    hosp_cross_streets,
    hosp_street_addr1,
    hosp_street_addr2,
    hosp_city,
    hosp_cnty,
    hosp_state,
    hosp_cntry,
    hosp_postal_cd,
    hosp_phone_num1,
    hosp_phone_num2,
    hosp_phone_num3,
    hosp_phone_num4,
    hosp_phone_num5,
    hosp_phone_num6,
    hosp_phone_num7,
    hosp_phone_num8,
    hosp_fax_num,
    hosp_open_dt,
    hosp_open_flg,
    store_open_dt,
    hosp_close_dt,
    hosp_cnvrtd_dt,
    hosp_relo_dt,
    hosp_time_zone_descr,
    hosp_updtd_hrs_dt,
    mon_open_hr,
    mon_close_hr,
    tue_open_hr,
    tue_close_hr,
    wed_open_hr,
    wed_close_hr,
    thu_open_hr,
    thu_close_hr,
    fri_open_hr,
    fri_close_hr,
    sat_open_hr,
    sat_close_hr,
    sun_open_hr,
    sun_close_hr,
    tot_wk_hrs_open,
    hosp_days_not_open,
    kennel_cnt,

    dw_create_dt,
    dw_begin_eff_dt,
    dw_end_eff_dt,
    dw_curr_row_ind,
    dw_deleted_ind,
    dw_job_id,
    dw_load_dt,

    fw_createdts,
    fw_modifiedts,
    fw_filename,
    rowhash,
    record_status
 )
select
hosp_num,
    frmr_hosp_num,
    hosp_typ,
    petsmart_vet_srvcs_flg,
    hosp_abbrv,
    store_num,
    hosp_long_nam,
    hosp_short_nam,
    hosp_region,
    regional_vp_full_nam,
    regional_vp_first_nam,
    regional_vp_last_nam,
    field_drctr_area,
    field_drctr_full_nam,
    field_drctr_first_nam,
    field_drctr_last_nam,
    field_trainer_full_nam,
    field_trainer_first_nam,
    field_trainer_last_nam,
    medical_drctr_full_nam,
    medical_drctr_first_nam,
    medical_drctr_last_nam,
    prctc_cnsltnt_full_nam,
    prctc_cnsltnt_first_nam,
    prctc_cnsltnt_last_nam,
    cos_full_nam,
    cos_first_nam,
    cos_last_nam,
    shopping_center_nam,
    hosp_cross_streets,
    hosp_street_addr1,
    hosp_street_addr2,
    hosp_city,
    hosp_cnty,
    hosp_state,
    hosp_cntry,
    hosp_postal_cd,
    hosp_phone_num1,
    hosp_phone_num2,
    hosp_phone_num3,
    hosp_phone_num4,
    hosp_phone_num5,
    hosp_phone_num6,
    hosp_phone_num7,
    hosp_phone_num8,
    hosp_fax_num,
    hosp_open_dt,
    hosp_open_flg,
    store_open_dt,
    hosp_close_dt,
    hosp_cnvrtd_dt,
    hosp_relo_dt,
    hosp_time_zone_descr,
    hosp_updtd_hrs_dt,
    mon_open_hr,
    mon_close_hr,
    tue_open_hr,
    tue_close_hr,
    wed_open_hr,
    wed_close_hr,
    thu_open_hr,
    thu_close_hr,
    fri_open_hr,
    fri_close_hr,
    sat_open_hr,
    sat_close_hr,
    sun_open_hr,
    sun_close_hr,
    tot_wk_hrs_open,
    hosp_days_not_open,
    kennel_cnt,

    dw_create_dt,
    dw_begin_eff_dt,
    dw_end_eff_dt,
    dw_curr_row_ind,
    dw_deleted_ind,
    dw_job_id,
    dw_load_dt,

    fw_createdts,
    fw_modifiedts,
    fw_filename,
    rowhash,
    record_status

from  ${banfield_catalog}.bfdw_bronze.cmn_tb_cmd_current_hosp
where record_status = 'valid';
