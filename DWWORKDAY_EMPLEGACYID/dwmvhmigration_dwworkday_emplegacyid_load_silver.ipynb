-- %%
%sql
insert overwrite table  ${banfield_catalog}.bfdw_silver.dwworkday_emplegacyid
( 
 wd_employee_id,
    oracle_id,
    bp_legacy_id,
    src_filename,
    dw_create_dt,
    dw_load_dt,
    dw_job_id,
    fw_createdts,
    fw_modifiedts,
    fw_filename,
    rowhash
 )
select
  wd_employee_id,
    oracle_id,
    bp_legacy_id,
    src_filename,
    dw_create_dt,
    dw_load_dt,
    dw_job_id,
    fw_createdts,
    fw_modifiedts,
    fw_filename,
    rowhash,
   

from  ${banfield_catalog}.bfdw_bronze.dwworkday_emplegacyid
where record_status = 'valid';
